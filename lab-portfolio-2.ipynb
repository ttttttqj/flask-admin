# %% [markdown]
# # Lab portfolio 2 Area of applicability
#
# This is a short practice exercise related to computing the area of applicability of a machine learning model (<a href="https://besjournals.onlinelibrary.wiley.com/doi/full/10.1111/2041-210X.13650" target="_blank">Meyer and Pebesma, 2021</a>). You have access to a dataset of predictor variables derived from a <a href="https://developers.google.com/earth-engine/datasets/catalog/COPERNICUS_S2_SR_HARMONIZED" target="_blank">Sentinel-2 satellite image</a> and topographic variables which correspond to points where there are leaf area index (LAI) measurements. The LAI measurements were derived from LiDAR data with a 30 cm spatial resolution and 15 cm vertical resolution averaged to a 10 m spatial resolution to match the size of Sentinel-2 pixels.
#
# LAI is a measure of the total area of leaves relative to the ground area and is an important biophysical variable for studying vegetation growth and functioning. The data we are using were collected over the Marburg Forest in Germany and are from the paper by <a href="https://www.sciencedirect.com/science/article/abs/pii/S0304380019303230" target="_blank">Meyer et al. (2019)</a>.

# %% [markdown]
# ## Setup
#
# ### Load data

# %%
import os
import subprocess

if "data-geoml" not in os.listdir(os.getcwd()):
    subprocess.run('wget "https://github.com/envt-5566/data/raw/main/data-geoml-2026.zip"', shell=True, capture_output=True, text=True)
    subprocess.run('unzip "data-geoml-2026.zip"', shell=True, capture_output=True, text=True)
    if "data-geoml-2026.zip" not in os.listdir(os.getcwd()):
        print("Has a directory called data-geoml been downloaded and placed in your working directory? If not, try re-executing this code chunk")
    else:
        print("Data download OK")

DATA_PATH = os.path.join(os.getcwd())
# Out:
# Data download OK

# %% [markdown]
# ### Load packages

# %%
if 'google.colab' in str(get_ipython()):
    # !pip install mapclassify
    # !pip install contextily
    # !pip install pysal

import os
import numpy as np
import pandas as pd
import geopandas as gpd

from math import log
from tqdm import tqdm

# plotting
import seaborn as sns
import matplotlib.pyplot as plt

# pre-processing
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# models
from sklearn.neural_network import MLPRegressor
from sklearn.cluster import KMeans

# distance metrics
from scipy.spatial import distance
# Out:
# Requirement already satisfied: mapclassify in /usr/local/lib/python3.13/dist-packages (2.10.0)
# Requirement already satisfied: networkx>=3.2 in /usr/local/lib/python3.13/dist-packages (from mapclassify) (3.6.1)
# Requirement already satisfied: numpy>=1.26 in /usr/local/lib/python3.13/dist-packages (from mapclassify) (2.1.3)
# Requirement already satisfied: pandas>=2.1 in /usr/local/lib/python3.13/dist-packages (from mapclassify) (2.2.3)
# Requirement already satisfied: scikit-learn>=1.4 in /usr/local/lib/python3.13/dist-packages (from mapclassify) (1.6.1)
# Requirement already satisfied: scipy>=1.12 in /usr/local/lib/python3.13/dist-packages (from mapclassify) (1.16.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.13/dist-packages (from pandas>=2.1->mapclassify) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.13/dist-packages (from pandas>=2.1->mapclassify) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.13/dist-packages (from pandas>=2.1->mapclassify) (2026.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.13/dist-packages (from scikit-learn>=1.4->mapclassify) (1.6.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.13/dist-packages (from scikit-learn>=1.4->mapclassify) (3.6.0)
# Requirement already satisfied: cloudpickle>=3.0 in /usr/local/lib/python3.13/dist-packages (from joblib>=1.2.0->scikit-learn>=1.4->mapclassify) (3.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.13/dist-packages (from python-dateutil>=2.8.2->pandas>=2.1->mapclassify) (1.17.0)
# Collecting contextily
#   Downloading contextily-1.7.1-py3-none-any.whl.metadata (3.1 kB)
# Requirement already satisfied: geopy in /usr/local/lib/python3.13/dist-packages (from contextily) (2.4.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.13/dist-packages (from contextily) (3.10.0)
# Collecting mercantile (from contextily)
#   Downloading mercantile-1.2.1-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: pillow in /usr/local/lib/python3.13/dist-packages (from contextily) (11.3.0)
# Requirement already satisfied: rasterio in /usr/local/lib/python3.13/dist-packages (from contextily) (1.5.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.13/dist-packages (from contextily) (2.32.4)
# Requirement already satisfied: joblib in /usr/local/lib/python3.13/dist-packages (from contextily) (1.6.0)
# Requirement already satisfied: xyzservices in /usr/local/lib/python3.13/dist-packages (from contextily) (2026.3.0)
# Requirement already satisfied: geographiclib<3,>=1.52 in /usr/local/lib/python3.13/dist-packages (from geopy->contextily) (2.1)
# Requirement already satisfied: cloudpickle>=3.0 in /usr/local/lib/python3.13/dist-packages (from joblib->contextily) (3.1.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.13/dist-packages (from matplotlib->contextily) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.13/dist-packages (from matplotlib->contextily) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.13/dist-packages (from matplotlib->contextily) (4.64.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.13/dist-packages (from matplotlib->contextily) (1.5.1)
# Requirement already satisfied: numpy>=1.23 in /usr/local/lib/python3.13/dist-packages (from matplotlib->contextily) (2.1.3)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.13/dist-packages (from matplotlib->contextily) (26.3)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.13/dist-packages (from matplotlib->contextily) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.13/dist-packages (from matplotlib->contextily) (2.9.0.post0)
# Requirement already satisfied: click>=3.0 in /usr/local/lib/python3.13/dist-packages (from mercantile->contextily) (8.5.0)
# Requirement already satisfied: affine in /usr/local/lib/python3.13/dist-packages (from rasterio->contextily) (3.0.1)
# Requirement already satisfied: attrs in /usr/local/lib/python3.13/dist-packages (from rasterio->contextily) (26.1.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.13/dist-packages (from rasterio->contextily) (2026.7.22)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.13/dist-packages (from requests->contextily) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.13/dist-packages (from requests->contextily) (3.19)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.13/dist-packages (from requests->contextily) (2.5.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.13/dist-packages (from python-dateutil>=2.7->matplotlib->contextily) (1.17.0)
# Downloading contextily-1.7.1-py3-none-any.whl (18 kB)
# Downloading mercantile-1.2.1-py3-none-any.whl (14 kB)
# Installing collected packages: mercantile, contextily
# Successfully installed contextily-1.7.1 mercantile-1.2.1
# Requirement already satisfied: pysal in /usr/local/lib/python3.13/dist-packages (25.7)
# Requirement already satisfied: beautifulsoup4>=4.10 in /usr/local/lib/python3.13/dist-packages (from pysal) (4.13.5)
# Requirement already satisfied: geopandas>=0.10.0 in /usr/local/lib/python3.13/dist-packages (from pysal) (1.1.4)
# Requirement already satisfied: numpy>=1.22 in /usr/local/lib/python3.13/dist-packages (from pysal) (2.1.3)
# Requirement already satisfied: packaging>=22 in /usr/local/lib/python3.13/dist-packages (from pysal) (26.3)
# Requirement already satisfied: pandas>=1.4 in /usr/local/lib/python3.13/dist-packages (from pysal) (2.2.3)
# Requirement already satisfied: platformdirs>=2.0.2 in /usr/local/lib/python3.13/dist-packages (from pysal) (4.11.7)
# Requirement already satisfied: requests>=2.27 in /usr/local/lib/python3.13/dist-packages (from pysal) (2.32.4)
# Requirement already satisfied: scipy>=1.8 in /usr/local/lib/python3.13/dist-packages (from pysal) (1.16.3)
# Requirement already satisfied: shapely>=2.0.1 in /usr/local/lib/python3.13/dist-packages (from pysal) (2.1.2)
# Requirement already satisfied: scikit-learn>=1.1 in /usr/local/lib/python3.13/dist-packages (from pysal) (1.6.1)
# Requirement already satisfied: libpysal>=4.13.0 in /usr/local/lib/python3.13/dist-packages (from pysal) (4.14.1)
# Requirement already satisfied: access>=1.1.9 in /usr/local/lib/python3.13/dist-packages (from pysal) (1.1.10.post3)
# Requirement already satisfied: esda>=2.7.1 in /usr/local/lib/python3.13/dist-packages (from pysal) (2.9.0)
# Requirement already satisfied: giddy>=2.3.6 in /usr/local/lib/python3.13/dist-packages (from pysal) (2.3.9)
# Requirement already satisfied: inequality>=1.1.2 in /usr/local/lib/python3.13/dist-packages (from pysal) (1.1.2)
# Requirement already satisfied: pointpats>=2.5.1 in /usr/local/lib/python3.13/dist-packages (from pysal) (2.5.5)
# Requirement already satisfied: segregation>=2.5.2 in /usr/local/lib/python3.13/dist-packages (from pysal) (2.5.4)
# Requirement already satisfied: spaghetti>=1.7.6 in /usr/local/lib/python3.13/dist-packages (from pysal) (1.7.6)
# Requirement already satisfied: mgwr>=2.2.1 in /usr/local/lib/python3.13/dist-packages (from pysal) (2.2.1)
# Requirement already satisfied: momepy>=0.10.0 in /usr/local/lib/python3.13/dist-packages (from pysal) (0.11.0)
# Requirement already satisfied: spglm>=1.1.0 in /usr/local/lib/python3.13/dist-packages (from pysal) (1.1.0)
# Requirement already satisfied: spint>=1.0.7 in /usr/local/lib/python3.13/dist-packages (from pysal) (1.1.0)
# Requirement already satisfied: spreg>=1.8.3 in /usr/local/lib/python3.13/dist-packages (from pysal) (1.9.0)
# Requirement already satisfied: tobler>=0.12.1 in /usr/local/lib/python3.13/dist-packages (from pysal) (0.14.0)
# Requirement already satisfied: mapclassify>=2.10.0 in /usr/local/lib/python3.13/dist-packages (from pysal) (2.10.0)
# Requirement already satisfied: splot>=1.1.7 in /usr/local/lib/python3.13/dist-packages (from pysal) (1.1.7)
# Requirement already satisfied: spopt>=0.7.0 in /usr/local/lib/python3.13/dist-packages (from pysal) (0.7.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.13/dist-packages (from beautifulsoup4>=4.10->pysal) (2.9.2)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.13/dist-packages (from beautifulsoup4>=4.10->pysal) (4.16.0)
# Requirement already satisfied: pyogrio>=0.7.2 in /usr/local/lib/python3.13/dist-packages (from geopandas>=0.10.0->pysal) (0.13.0)
# Requirement already satisfied: pyproj>=3.5.0 in /usr/local/lib/python3.13/dist-packages (from geopandas>=0.10.0->pysal) (3.7.2)
# Requirement already satisfied: quantecon>=0.8 in /usr/local/lib/python3.13/dist-packages (from giddy>=2.3.6->pysal) (0.11.4)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.13/dist-packages (from giddy>=2.3.6->pysal) (0.13.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.13/dist-packages (from giddy>=2.3.6->pysal) (3.10.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.13/dist-packages (from libpysal>=4.13.0->pysal) (3.1.6)
# Requirement already satisfied: networkx>=3.2 in /usr/local/lib/python3.13/dist-packages (from mapclassify>=2.10.0->pysal) (3.6.1)
# Requirement already satisfied: tqdm>=4.65 in /usr/local/lib/python3.13/dist-packages (from momepy>=0.10.0->pysal) (4.67.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.13/dist-packages (from pandas>=1.4->pysal) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.13/dist-packages (from pandas>=1.4->pysal) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.13/dist-packages (from pandas>=1.4->pysal) (2026.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.13/dist-packages (from requests>=2.27->pysal) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.13/dist-packages (from requests>=2.27->pysal) (3.19)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.13/dist-packages (from requests>=2.27->pysal) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.13/dist-packages (from requests>=2.27->pysal) (2026.7.22)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.13/dist-packages (from scikit-learn>=1.1->pysal) (1.6.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.13/dist-packages (from scikit-learn>=1.1->pysal) (3.6.0)
# Requirement already satisfied: deprecation in /usr/local/lib/python3.13/dist-packages (from segregation>=2.5.2->pysal) (2.1.0)
# Requirement already satisfied: numba in /usr/local/lib/python3.13/dist-packages (from segregation>=2.5.2->pysal) (0.61.2)
# Requirement already satisfied: rtree>=1.0 in /usr/local/lib/python3.13/dist-packages (from spaghetti>=1.7.6->pysal) (1.4.1)
# Requirement already satisfied: pulp>=2.8 in /usr/local/lib/python3.13/dist-packages (from spopt>=0.7.0->pysal) (3.3.2)
# Requirement already satisfied: rasterio>=1.4 in /usr/local/lib/python3.13/dist-packages (from tobler>=0.12.1->pysal) (1.5.1)
# Requirement already satisfied: rasterstats>=0.20 in /usr/local/lib/python3.13/dist-packages (from tobler>=0.12.1->pysal) (0.21.0)
# Requirement already satisfied: statsmodels>=0.14 in /usr/local/lib/python3.13/dist-packages (from tobler>=0.12.1->pysal) (0.15.0)
# Requirement already satisfied: cloudpickle>=3.0 in /usr/local/lib/python3.13/dist-packages (from joblib>=1.2.0->scikit-learn>=1.1->pysal) (3.1.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.13/dist-packages (from matplotlib->giddy>=2.3.6->pysal) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.13/dist-packages (from matplotlib->giddy>=2.3.6->pysal) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.13/dist-packages (from matplotlib->giddy>=2.3.6->pysal) (4.64.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.13/dist-packages (from matplotlib->giddy>=2.3.6->pysal) (1.5.1)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.13/dist-packages (from matplotlib->giddy>=2.3.6->pysal) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.13/dist-packages (from matplotlib->giddy>=2.3.6->pysal) (3.3.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.13/dist-packages (from python-dateutil>=2.8.2->pandas>=1.4->pysal) (1.17.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.13/dist-packages (from quantecon>=0.8->giddy>=2.3.6->pysal) (1.14.0)
# Requirement already satisfied: llvmlite<0.45,>=0.44.0dev0 in /usr/local/lib/python3.13/dist-packages (from numba->segregation>=2.5.2->pysal) (0.44.0)
# Requirement already satisfied: affine in /usr/local/lib/python3.13/dist-packages (from rasterio>=1.4->tobler>=0.12.1->pysal) (3.0.1)
# Requirement already satisfied: attrs in /usr/local/lib/python3.13/dist-packages (from rasterio>=1.4->tobler>=0.12.1->pysal) (26.1.0)
# Requirement already satisfied: click!=8.2.*,>=4.0 in /usr/local/lib/python3.13/dist-packages (from rasterio>=1.4->tobler>=0.12.1->pysal) (8.5.0)
# Requirement already satisfied: cligj>=0.4 in /usr/local/lib/python3.13/dist-packages (from rasterstats>=0.20->tobler>=0.12.1->pysal) (0.7.2)
# Requirement already satisfied: simplejson in /usr/local/lib/python3.13/dist-packages (from rasterstats>=0.20->tobler>=0.12.1->pysal) (4.1.2)
# Requirement already satisfied: patsy>=0.5.6 in /usr/local/lib/python3.13/dist-packages (from statsmodels>=0.14->tobler>=0.12.1->pysal) (1.0.3)
# Requirement already satisfied: formulaic>=1.1.0 in /usr/local/lib/python3.13/dist-packages (from statsmodels>=0.14->tobler>=0.12.1->pysal) (1.2.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.13/dist-packages (from jinja2->libpysal>=4.13.0->pysal) (3.0.3)
# Requirement already satisfied: interface-meta>=1.2.0 in /usr/local/lib/python3.13/dist-packages (from formulaic>=1.1.0->statsmodels>=0.14->tobler>=0.12.1->pysal) (2.0.1)
# Requirement already satisfied: narwhals>=1.17 in /usr/local/lib/python3.13/dist-packages (from formulaic>=1.1.0->statsmodels>=0.14->tobler>=0.12.1->pysal) (2.25.0)
# Requirement already satisfied: wrapt>=1.17.0rc1 in /usr/local/lib/python3.13/dist-packages (from formulaic>=1.1.0->statsmodels>=0.14->tobler>=0.12.1->pysal) (2.4.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.13/dist-packages (from sympy->quantecon>=0.8->giddy>=2.3.6->pysal) (1.3.0)

# %%
gdf = gpd.read_file(os.path.join(DATA_PATH, "data-geoml", "lai_meyer_et_al_2019_marburg.geojson"))
gdf = gdf.drop(columns=["field_1", "ID", "x_utm_25832", "y_utm_25832"])
gdf = gdf.to_crs("EPSG:4326")

# %% [markdown]
# ## Activity
#
# To compute the area of applicability of a machine learning model we need to i) measure how similar the predictor variables are at a candidate location for prediction to the training data used to develop the model; <a href="https://besjournals.onlinelibrary.wiley.com/doi/full/10.1111/2041-210X.13650" target="_blank">Meyer and Pebesma (2021)</a> present a dissimilarity index for this task, and ii) determine a threshold dissimilarity index value which delineates the coverage of the training dataset; again <a href="https://besjournals.onlinelibrary.wiley.com/doi/full/10.1111/2041-210X.13650" target="_blank">Meyer and Pebesma (2021)</a> present a method for this. **Can you adapt the examples from the *area of applicability* notebook to compute the dissimilarity index threshold for the training dataset to develop predictive models of LAI?**
#
# You will need to consider:
#
# * What variables to drop before model training.
# * Do you need to fit or train a model? If not, you can pass `None` as the model argument to `compute_di_threshold()`.
# * Should you use random or spatial k-fold cross-validation.
#
# **Your written response should state**:
#
# * The dissimilarity index threshold that you have computed.
# * Whether you used random or spatial k-fold cross-validation and a short justification for the cross-validation approach taken (max: 2 to 3 sentences).
#
# We have copied over the functions from the *area of applicability* notebook to help you.

# %% [markdown]
# ### Dissimilarity Index
#
# The dissimilarity index is a measure of the distance between a candidate location for prediction using the machine learning model and the model's training data. It measures distance in predictor variable space and is a measure of how similar the predictor variable values are to the most similar example in the training dataset. The process to compute the dissimilarity index is:
#
# 1. Compute the Euclidean distance between the predictor variables for the candidate location and every example in the training dataset.
# 2. Select the minimum distance.
# 3. Compute the average Euclidean distance between predictor variables for all examples in the training dataset.
# 4. Divide the minimum distance between the candidate prediction location and the training dataset (2) by the average distance between predictor variables in the training dataset (3).
#
# The dissimilarity index for the candidate prediction location is the result of step 4. Standardising the dissimilarity index values by dividing by the average distance between predictor variables in the training dataset means that dissimilarity index values range from 0 to infinity. If the dissimilarity index value is 0 then the candidate prediction location is identical to an example in the training dataset.
#
# The following is a helper function that implements steps 2.1, 2.3 and 2.4 in Meyer and Pebesma (2021) and computes the dissimilarity index given arrays of predictor variables for the training dataset and candidate predictor locations.

# %%
def compute_di(X_train, X_preds, dbar, scaled):
    """Compute the Dissimilarity Index (DI).

    This is based on steps 2.1, 2.3, and 2.4 in Meyer and Pebesma (2021).

    Note, we omit the weighting of predictor variables (step 2.2 of Meyer and Pebesma (2021).

    Args:
        X_train (ndarray): Array of training data where examples are aligned on the 0 axis and features on the 1 axis.
        X_preds (ndarray): Array of predictor data where examples are aligned on the 0 axis and features on the 1 axis.
        dbar (float | None): Precomputed mean of dissimilarity index for all values in the training dataset.
        scaled (bool): Flag to indicate if input data is already standardised.

    Returns:
        ndarray, an array of DI values for each example in the prediction set.
    """

    # standardise predictors (using training data)
    if scaled:
        X_train_scaled = X_train
        X_preds_scaled = X_preds
    else:
        scaler = StandardScaler().fit(X_train)
        X_train_scaled = scaler.transform(X_train)
        X_preds_scaled = scaler.transform(X_preds)

    # Compute dissimilarity index (DI)
    # Section 2.3 in Meyer and Pebesma (2021)

    # create a matrix to store Euclidean distance between
    # all training points and prediction points
    n_X_train = X_train_scaled.shape[0]
    n_X_preds = X_preds_scaled.shape[0]

    d_arr = distance.cdist(X_train_scaled, X_preds_scaled, "euclidean")

    # get the minimum distance between each point in x_preds
    # and the training set
    d_arr = np.min(d_arr, axis=0)

    # Section 2.4 in Meyer and Pebesma (2021)
    if dbar:
        di = d_arr / dbar
    else:
        # compute average distance between all
        # training points to standardise DI
        d_train_arr = distance.cdist(X_train_scaled, X_train_scaled, "euclidean")
        # keep only the upper right triangly
        # this ensures we only compare each training point
        # to another training point once
        mask = np.triu(np.ones((n_X_train, n_X_train)), 1) > 0
        d_train_arr = d_train_arr[mask]

        di = d_arr / np.mean(d_train_arr)

    return di

# %%
def compute_dbar(X_train, scaled):
    """Compute average DI between all values in the training dataset.

    d_bar is computed section 2.4 in Meyer and Pebesma (2021). It is
    used to standardise dissimilarity index values.

    Precomputing can save time when the training dataset is fixed and we
    want to iterate over a range of candidate prediction locations.
    """
    # standardise predictors (using training data)
    if scaled:
        X_train_scaled = X_train
    else:
        scaler = StandardScaler().fit(X_train)
        X_train_scaled = scaler.transform(X_train)

    n_X_train = X_train.shape[0]

    # Section 2.4 in Meyer and Pebesma (2021)

    # compute average distance between all
    # training points to standardise DI
    d_train_arr = distance.cdist(X_train_scaled, X_train_scaled, "euclidean")
    # keep only the upper right triangly
    # this ensures we only compare each training point
    # to another training point once
    mask = np.triu(np.ones((n_X_train, n_X_train)), 1) > 0
    d_train_arr = d_train_arr[mask]

    return np.mean(d_train_arr)

# %% [markdown]
# ### Dissimilarity index threshold
#
# Meyer and Pebesma (2021) in section 2.5 compute a dissimilarity index threshold which represents the outlier removed maximum dissimilarity of the training dataset. This represents a threshold for the model's area of applicability. If a candidate prediction location has a dissimilarity index greater than this threshold it is deemed outside the model's area of applicability.
#
# The dissimilarity index threshold is computed using k-fold cross-validation on the training dataset:
#
# 1. Split the training dataset into $k$ folds.
# 2. Hold out each $k$ fold in-turn:
#     * Compute the dissimilarity index between all values in the hold-out fold and training folds.
#     * Optional step: Compute model predictions and error for all values in the hold-out fold.
# 3. Compute the outlier-removed threshold as the 75th percentile dissimilarity index value + (1.5 * IQR)
#
# The following helper function computes the dissimilarity index threshold given the training data as a `GeoDataFrame`.

# %%
def compute_di_threshold(gdf, n_folds, model, spatial_cv, target_column, predictors):
    """
    Function to compute DI threshold following Meyer and Pebesma (2021).

    The DI threshold is computed as the 75th percentile + (1.5 * IQR). DI threshold is
    considered the outlier removed maximum DI of the training data set. Data points with a
    DI greater than the DI threshold are outside the area of applicability of the model
    given the training data.

    Args:
        gdf (GeoDataFrame): The spatial dataset (GeoDataFrame) containing features and the target variable.
        n_folds (int): The number of folds to use for cross-validation.
        model: The machine learning model to train and evaluate (or None to only compute DI values).
        spatial_cv (bool): If `True`, use k-fold spatial cross-validation. Otherwise, use k-fold random cross-validation.
        target_column (str): The column name for the target variable.
        predictors (list): Columns to use as predictors.

    Returns:
        dict, dict object with the DI threshold, the DI values for the hold out folds, the targets,
        the predictions and the errors for the hold out folds, and the fold each example was held out in.

    """
    # Section 2.5 in Meyer and Pebesma (2021)
    gdf_tmp = gdf.copy()

    if spatial_cv:
        # split the data into n_folds spatially
        # cluster the x and y coordinates of the grid cell centroids
        centroids = gdf_tmp.geometry.centroid
        X_xy = np.column_stack([centroids.x, centroids.y])

        # create a KMeans clusterer
        km = KMeans(
            n_clusters=n_folds,
            init="random",
            n_init=10,
            max_iter=300,
            tol=1e-04,
            random_state=123,
        )
        gdf_tmp["fold"] = km.fit_predict(X_xy)

    else:
        # split the data into n_folds
        # shuffle the GeoDataFrame
        gdf_tmp = gdf_tmp.sample(frac=1, random_state=123)

        # assign a fold id using the modulo operation
        gdf_tmp["fold"] = np.arange(len(gdf_tmp)) % n_folds

    # standardise predictors
    scaler = StandardScaler().fit(gdf_tmp.loc[:, predictors])
    X_scaled = scaler.transform(gdf_tmp.loc[:, predictors])
    y = gdf_tmp.loc[:, target_column].to_numpy()
    folds = gdf_tmp.loc[:, "fold"].to_numpy()

    # get dbar of the whole training dataset
    dbar = compute_dbar(X_scaled, True)

    # lists to store DI's, targets, predictions and errors on the hold out folds
    dis = []
    targets = []
    predictions = []
    errors = []
    hold_out_folds = []

    # loop over folds and compute DI
    for k in range(0, n_folds):
        # boolean masks for the hold out fold and training folds
        test = folds == k
        train = folds != k

        # use compute_di function previously defined
        fold_dis = compute_di(X_scaled[train], X_scaled[test], dbar, scaled=True)
        dis = dis + fold_dis.tolist()
        targets = targets + y[test].tolist()
        hold_out_folds = hold_out_folds + [k] * int(test.sum())

        # train model
        if model:
            m = model.fit(X_scaled[train], y[train])

            # compute predictions and error using the hold out fold
            y_test_preds = m.predict(X_scaled[test])
            predictions = predictions + y_test_preds.tolist()
            errors = errors + (y_test_preds - y[test]).tolist()

    # compute DI threshold
    # 75th percentile 1.5 * IQR as in Meyer and Pebesma (2021)
    iqr = np.percentile(dis, 75) - np.percentile(dis, 25)
    di_threshold = np.percentile(dis, 75) + (1.5 * iqr)

    output = {}
    output["di_threshold"] = di_threshold
    output["di"] = dis
    output["targets"] = targets
    output["predictions"] = predictions
    output["errors"] = errors
    output["fold"] = hold_out_folds

    return output

# %%
predictors = ["B02","B03","B04","B05","B06","B07","B08","B8A","B11","B12",
              "dem","slope","aspect"]
target = "LAI"

# 转投影坐标，让 spatial CV 的 KMeans 按米聚类
gdf_proj = gdf.to_crs("EPSG:25832")

# model=None：只算 DI，不训练模型
di_random  = compute_di_threshold(gdf_proj, 10, None, False, target, predictors)
di_spatial = compute_di_threshold(gdf_proj, 10, None, True,  target, predictors)

print(f"DI threshold (random k-fold CV):  {di_random['di_threshold']:.4f}")
print(f"DI threshold (spatial k-fold CV): {di_spatial['di_threshold']:.4f}")
# Out:
# DI threshold (random k-fold CV):  0.2516
# DI threshold (spatial k-fold CV): 0.5751

# %% [markdown]
# DI threshold (random k-fold CV):  0.2516
#
# DI threshold (spatial k-fold CV): 0.5751
#
# I used spatial k-fold cross-validation because the LAI data points are densely sampled and strongly spatially autocorrelated, so nearby points have similar values. With random k-fold cross-validation, each held-out point has a training point right next to it, so the threshold (0.2516) only reflects how dissimilar a point is from its immediate neighbours. Spatial k-fold cross-validation mimics predicting in unsampled areas, so its threshold (0.5751) better matches how the model would be used.
